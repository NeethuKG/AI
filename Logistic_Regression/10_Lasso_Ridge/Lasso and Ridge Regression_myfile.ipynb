# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load data
data=pd.read_csv(r"Melbourne_housing_FULL.csv")
data.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
data.describe(include='all')
# Out:
#            Suburb       Address         Rooms   Type         Price Method  \
# count       34857         34857  34857.000000  34857  2.724700e+04  34857
# unique        351         34009           NaN      3           NaN      9
# top     Reservoir  5 Charles St           NaN      h           NaN      S
# freq          844             6           NaN  23980           NaN  19744
# mean          NaN           NaN      3.031012    NaN  1.050173e+06    NaN
# std           NaN           NaN      0.969933    NaN  6.414671e+05    NaN
# min           NaN           NaN      1.000000    NaN  8.500000e+04    NaN
# 25%           NaN           NaN      2.000000    NaN  6.350000e+05    NaN
# 50%           NaN           NaN      3.000000    NaN  8.700000e+05    NaN
# 75%           NaN           NaN      4.000000    NaN  1.295000e+06    NaN
# max           NaN           NaN     16.000000    NaN  1.120000e+07    NaN
#
#        SellerG        Date      Distance      Postcode  ...      Bathroom  \
# ...

# %%
data.size
# Out:
# 731997

# %%
data.shape
# Out:
# (34857, 21)

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data1=data.drop_duplicates()

# %%
data1.isnull()
# Out:
#        Suburb  Address  Rooms   Type  Price  Method  SellerG   Date  Distance  \
# 0       False    False  False  False   True   False    False  False     False
# 1       False    False  False  False  False   False    False  False     False
# 2       False    False  False  False  False   False    False  False     False
# 3       False    False  False  False   True   False    False  False     False
# 4       False    False  False  False  False   False    False  False     False
# ...       ...      ...    ...    ...    ...     ...      ...    ...       ...
# 34852   False    False  False  False  False   False    False  False     False
# 34853   False    False  False  False  False   False    False  False     False
# 34854   False    False  False  False  False   False    False  False     False
# 34855   False    False  False  False  False   False    False  False     False
# 34856   False    False  False  False  False   False    False  False     False
#
# ...

# %%
data1.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7609
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
data1.Bedroom2.unique()
# Out:
# array([ 2.,  3.,  4.,  6., nan,  1.,  5.,  7.,  0.,  8.,  9., 30., 20.,
#        10., 16., 12.])

# %%
#Mean Imputation
mean=data1.Bedroom2.mean()
data1.Bedroom2.fillna(mean,inplace=True)

# %%
data1.Bedroom2.isnull().sum()
# Out:
# 0

# %%
data1.Bathroom.unique()
# Out:
# array([ 1.,  2., nan,  3.,  7.,  4.,  0.,  5.,  6., 12.,  8.,  9.])

# %%
#Mean imputation
mean=data1.Bathroom.mean()
data1.Bathroom.fillna(mean,inplace=True)

# %%
data1.Bathroom.isnull().sum()
# Out:
# 0

# %%
data1.corr()
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.465238  0.271513  0.085890  0.819099  0.529234
# Price          0.465238  1.000000 -0.211384  0.044950  0.380414  0.379460
# Distance       0.271513 -0.211384  1.000000  0.481567  0.239094  0.111909
# Postcode       0.085890  0.044950  0.481567  1.000000  0.080398  0.108109
# Bedroom2       0.819099  0.380414  0.239094  0.080398  1.000000  0.614785
# Bathroom       0.529234  0.379460  0.111909  0.108109  0.614785  1.000000
# Car            0.393880  0.201803  0.241831  0.067885  0.388492  0.307520
# Landsize       0.037402  0.032748  0.060864  0.040665  0.037018  0.036340
# BuildingArea   0.156231  0.100754  0.076295  0.042436  0.154159  0.147554
# YearBuilt     -0.012743 -0.333306  0.323035  0.089800 -0.002017  0.167862
# Lattitude      0.004871 -0.215607 -0.100414 -0.231026  0.003433 -0.058929
# Longtitude     0.103244  0.197874  0.200923  0.362901  0.105772  0.106032
# ...

# %%
#random Sample Imputation 
data1['Car_random']=data1['Car']
random_sample = data1['Car'].dropna().sample(data1.Car.isnull().sum(),random_state=0)
#random_sample
random_sample.index=data1[data1['Car'].isnull()].index
data1.loc[data1.Car.isnull(),'Car_random']=random_sample
data1.drop('Car',axis=1,inplace=True)

# %%
data1.Car_random.isnull().sum()
# Out:
# 0

# %%
data['Landsize'] = data['Landsize'].fillna(data.Landsize.mean())

# %%
#random Sample Imputation 
#data1['BuildingArea_random']= data1['BuildingArea']
#random_sample = data1['BuildingArea'].dropna().sample(data1['BuildingArea'].isnull().sum(),random_state=0)

#random_sample
##pandas need to have same index in order to merge the dataset
#random_sample.index=data1[data1['BuildingArea'].isnull()].index
#data1.loc[data1.BuildingArea.isnull(),'BuildingArea_random']=random_sample

# %%
data1['Landsize'] = data1['Landsize'].fillna(data1.Landsize.mean())
data1['BuildingArea'] = data1['BuildingArea'].fillna(data1.BuildingArea.mean())
data1['YearBuilt'] = data1['YearBuilt'].fillna(data1.YearBuilt.mean())
data1.CouncilArea = data1.CouncilArea.fillna(0)
data1['Lattitude'] = data1['Lattitude'].fillna(data1.Lattitude.mean())
data1['Longtitude'] = data1['Longtitude'].fillna(data1.Longtitude.mean())
data1['Regionname'] = data1['Regionname'].fillna(data1.Regionname.mode()[0])
data1.Propertycount = data1.Propertycount.fillna(0)
data1.Postcode=data1.Postcode.fillna(0)
data1.Distance=data1['Distance'].fillna(data1.Distance.mean())

# %%
data1.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            7609
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Landsize            0
# BuildingArea        0
# YearBuilt           0
# CouncilArea         0
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# Car_random          0
# dtype: int64

# %%
data1.dropna(inplace=True)

# %%
data1.shape
# Out:
# (27247, 21)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27247 entries, 1 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27247 non-null  object
#  1   Address        27247 non-null  object
#  2   Rooms          27247 non-null  int64
#  3   Type           27247 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         27247 non-null  object
#  6   SellerG        27247 non-null  object
#  7   Date           27247 non-null  object
#  8   Distance       27247 non-null  float64
#  9   Postcode       27247 non-null  float64
#  10  Bedroom2       27247 non-null  float64
#  11  Bathroom       27247 non-null  float64
#  12  Landsize       27247 non-null  float64
#  13  BuildingArea   27247 non-null  float64
#  14  YearBuilt      27247 non-null  float64
#  15  CouncilArea    27247 non-null  object
#  16  Lattitude      27247 non-null  float64
# ...

# %%
# Frequency or count Encoding: Imputing Suburb
data1.Suburb.nunique()
# Out:
# 345

# %%
data1.Suburb.value_counts()
# Out:
# Reservoir         727
# Bentleigh East    493
# Richmond          439
# Preston           415
# Brunswick         387
#                  ...
# Coldstream          1
# Ferny Creek         1
# Kalkallo            1
# viewbank            1
# Wandin North        1
# Name: Suburb, Length: 345, dtype: int64

# %%
Suburb_map = data1['Suburb'].value_counts().to_dict()
Suburb_map
# Out:
# {'Reservoir': 727,
#  'Bentleigh East': 493,
#  'Richmond': 439,
#  'Preston': 415,
#  'Brunswick': 387,
#  'Essendon': 361,
#  'Northcote': 345,
#  'Glenroy': 342,
#  'South Yarra': 328,
#  'Glen Iris': 323,
#  'Brighton': 317,
#  'Kew': 313,
#  'Hawthorn': 310,
#  'Pascoe Vale': 308,
#  'Coburg': 305,
#  'St Kilda': 303,
#  'Balwyn North': 297,
#  'Camberwell': 280,
#  'Bentleigh': 273,
#  'Port Melbourne': 268,
#  'Thornbury': 267,
#  'Brighton East': 266,
#  'Yarraville': 250,
#  'Moonee Ponds': 243,
#  'Carnegie': 230,
#  'Balwyn': 224,
#  'Malvern East': 223,
#  'Footscray': 221,
#  'Ascot Vale': 221,
#  'Hampton': 220,
#  'Prahran': 212,
#  'Keilor East': 212,
#  'Newport': 211,
#  'Craigieburn': 211,
#  'Brunswick West': 206,
#  'Doncaster': 204,
#  'Elwood': 201,
#  'Surrey Hills': 201,
#  'Hawthorn East': 194,
#  'Maribyrnong': 193,
#  'Sunshine': 182,
#  'Kensington': 180,
#  'Templestowe Lower': 177,
#  'Williamstown': 175,
#  'Toorak': 172,
#  'Fawkner': 172,
# ...

# %%
data1['Suburb'] = data1['Suburb'].map(Suburb_map)
data1.head(10)
# Out:
#     Suburb           Address  Rooms Type      Price Method SellerG       Date  \
# 1      102      85 Turner St      2    h  1480000.0      S  Biggin  3/12/2016
# 2      102   25 Bloomburg St      2    h  1035000.0      S  Biggin  4/02/2016
# 4      102      5 Charles St      3    h  1465000.0     SP  Biggin  4/03/2017
# 5      102  40 Federation La      3    h   850000.0     PI  Biggin  4/03/2017
# 6      102       55a Park St      4    h  1600000.0     VB  Nelson  4/06/2016
# 10     102    129 Charles St      2    h   941000.0      S  Jellis  7/05/2016
# 11     102      124 Yarra St      3    h  1876000.0      S  Nelson  7/05/2016
# 14     102     98 Charles St      2    h  1636000.0      S  Nelson  8/10/2016
# 15     102  217 Langridge St      3    h  1000000.0      S  Jellis  8/10/2016
# 16     102   18a Mollison St      2    t   745000.0      S  Jellis  8/10/2016
#
#     Distance  Postcode  ...  Bathroom    Landsize  BuildingArea    YearBuilt  \
# ...

# %%
#Address Encoding:(Frequency Encoding)
data1.Address.nunique()
# Out:
# 26751

# %%
data1.Address.value_counts()
# Out:
# 5 Charles St         4
# 13 George St         3
# 36 Aberfeldie St     3
# 13 Robinson St       3
# 53 William St        3
#                     ..
# 18 Barries Pl        1
# 20 Ivanhoe Av        1
# 74 Roycroft Av       1
# 3/13 Sylvester St    1
# 6/59 Albion St       1
# Name: Address, Length: 26751, dtype: int64

# %%
Address_map = data1.Address.value_counts().to_dict()
Address_map
# Out:
# {'5 Charles St': 4,
#  '13 George St': 3,
#  '36 Aberfeldie St': 3,
#  '13 Robinson St': 3,
#  '53 William St': 3,
#  '16 Smith St': 3,
#  '5 Margaret St': 3,
#  '7 Churchill Av': 3,
#  '14 Northcote St': 3,
#  '14 James St': 3,
#  '28 Blair St': 3,
#  '1/1 Clarendon St': 3,
#  '12 Mirams St': 3,
#  '14 Rose St': 3,
#  '2 Bruce St': 3,
#  '14 Arthur St': 3,
#  '25 William St': 3,
#  '2/13 Walker St': 2,
#  '38 Whalley St': 2,
#  '15 George St': 2,
#  '8 Monash Av': 2,
#  '2/7 Gordon St': 2,
#  '24/18 Station Rd': 2,
#  '84 May St': 2,
#  '46 Chapel St': 2,
#  '1 Daisy St': 2,
#  '20 Butler St': 2,
#  '30 Allendale Rd': 2,
#  '6 Hamilton St': 2,
#  '7A Downland Sq': 2,
#  '35 Queen Cct': 2,
#  '2/26 Renown St': 2,
#  '105 Mitford St': 2,
#  '14 Lennox St': 2,
#  '8 Outlook Dr': 2,
#  '2/52 Railway Pde': 2,
#  '9 Katta Ct': 2,
#  '1 Seaholme Av': 2,
#  '2/619 Toorak Rd': 2,
#  '13 Wood St': 2,
#  '3 Diosma Ct': 2,
#  '27 Edward St': 2,
#  '3 Clive Ct': 2,
#  '105/2 Beavers Rd': 2,
# ...

# %%
data1.Address=data1.Address.map(Address_map)

# %%
data1.head(10)
# Out:
#     Suburb  Address  Rooms Type      Price Method SellerG       Date  \
# 1      102        1      2    h  1480000.0      S  Biggin  3/12/2016
# 2      102        1      2    h  1035000.0      S  Biggin  4/02/2016
# 4      102        4      3    h  1465000.0     SP  Biggin  4/03/2017
# 5      102        1      3    h   850000.0     PI  Biggin  4/03/2017
# 6      102        1      4    h  1600000.0     VB  Nelson  4/06/2016
# 10     102        1      2    h   941000.0      S  Jellis  7/05/2016
# 11     102        1      3    h  1876000.0      S  Nelson  7/05/2016
# 14     102        1      2    h  1636000.0      S  Nelson  8/10/2016
# 15     102        1      3    h  1000000.0      S  Jellis  8/10/2016
# 16     102        1      2    t   745000.0      S  Jellis  8/10/2016
#
#     Distance  Postcode  ...  Bathroom    Landsize  BuildingArea    YearBuilt  \
# 1        2.5    3067.0  ...  1.000000  202.000000    160.251616  1965.287653
# ...

# %%
#Imputing Type:
data1.Type.nunique()
# Out:
# 3

# %%
data1.Type.value_counts()
# Out:
# h    18472
# u     5909
# t     2866
# Name: Type, dtype: int64

# %%
data1=pd.get_dummies(data1,columns=['Type'],drop_first =True)

# %%
data1.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Price', 'Method', 'SellerG', 'Date',
#        'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Landsize',
#        'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude',
#        'Regionname', 'Propertycount', 'Car_random', 'Type_t', 'Type_u'],
#       dtype='object')

# %%
#Encoding Method:
data1.Method.unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
data1=pd.get_dummies(data1,columns=['Method'],drop_first =True)

# %%
data1.head(10)
# Out:
#     Suburb  Address  Rooms      Price SellerG       Date  Distance  Postcode  \
# 1      102        1      2  1480000.0  Biggin  3/12/2016       2.5    3067.0
# 2      102        1      2  1035000.0  Biggin  4/02/2016       2.5    3067.0
# 4      102        4      3  1465000.0  Biggin  4/03/2017       2.5    3067.0
# 5      102        1      3   850000.0  Biggin  4/03/2017       2.5    3067.0
# 6      102        1      4  1600000.0  Nelson  4/06/2016       2.5    3067.0
# 10     102        1      2   941000.0  Jellis  7/05/2016       2.5    3067.0
# 11     102        1      3  1876000.0  Nelson  7/05/2016       2.5    3067.0
# 14     102        1      2  1636000.0  Nelson  8/10/2016       2.5    3067.0
# 15     102        1      3  1000000.0  Jellis  8/10/2016       2.5    3067.0
# 16     102        1      2   745000.0  Jellis  8/10/2016       2.5    3067.0
#
#     Bedroom2  Bathroom  ...  Longtitude             Regionname  Propertycount  \
# ...

# %%
data1.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Price', 'SellerG', 'Date', 'Distance',
#        'Postcode', 'Bedroom2', 'Bathroom', 'Landsize', 'BuildingArea',
#        'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname',
#        'Propertycount', 'Car_random', 'Type_t', 'Type_u', 'Method_S',
#        'Method_SA', 'Method_SP', 'Method_VB'],
#       dtype='object')

# %%
#SellerG: Frequency Encoding:
data1.SellerG.nunique()
# Out:
# 349

# %%
data1.SellerG.value_counts()
# Out:
# Nelson           2735
# Jellis           2532
# Barry            2393
# hockingstuart    2110
# Ray              1581
#                  ...
# Batty               1
# Nicholas            1
# Free                1
# iOne                1
# Mindacom            1
# Name: SellerG, Length: 349, dtype: int64

# %%
SellerG_map=data1.SellerG.value_counts().to_dict()
SellerG_map
# Out:
# {'Nelson': 2735,
#  'Jellis': 2532,
#  'Barry': 2393,
#  'hockingstuart': 2110,
#  'Ray': 1581,
#  'Buxton': 1431,
#  'Marshall': 1219,
#  'Biggin': 650,
#  'Fletchers': 616,
#  'Brad': 612,
#  'Woodards': 562,
#  'McGrath': 492,
#  'Greg': 426,
#  'YPA': 413,
#  'Noel': 410,
#  'Jas': 409,
#  'Stockdale': 378,
#  'Sweeney': 376,
#  'Miles': 360,
#  'RT': 351,
#  'Harcourts': 335,
#  'Gary': 332,
#  'Hodges': 313,
#  'Raine': 286,
#  'HAR': 241,
#  'Love': 224,
#  'RW': 219,
#  'Kay': 200,
#  "O'Brien": 192,
#  'Village': 177,
#  'Williams': 177,
#  'Douglas': 165,
#  'C21': 136,
#  'Purplebricks': 126,
#  'Chisholm': 121,
#  'Philip': 111,
#  'Buckingham': 110,
#  'Eview': 109,
#  'Rendina': 104,
#  'Darren': 103,
#  'Collins': 98,
#  'Morrison': 97,
#  'Bells': 85,
#  'Cayzer': 81,
#  'LJ': 78,
#  'Moonee': 78,
#  'Thomson': 78,
#  'McDonald': 75,
#  'Frank': 72,
#  'Nick': 72,
#  'Alexkarbon': 67,
#  'LITTLE': 61,
#  'Burnham': 59,
#  'Considine': 58,
#  'FN': 55,
#  'Prof.': 55,
# ...

# %%
data1.SellerG = data1.SellerG.map(SellerG_map)
data1.SellerG
# Out:
# 1         650
# 2         650
# 4         650
# 5         650
# 6        2735
#          ...
# 34852     409
# 34853     376
# 34854     409
# 34855    2110
# 34856     219
# Name: SellerG, Length: 27247, dtype: int64

# %%
data1.Date.nunique()
# Out:
# 78

# %%
data1.Date.value_counts()
# Out:
# 28/10/2017    879
# 17/03/2018    753
# 9/12/2017     723
# 24/02/2018    723
# 25/11/2017    682
#              ...
# 4/02/2016      35
# 30/09/2017     18
# 20/01/2018     12
# 27/01/2018     11
# 28/01/2016      2
# Name: Date, Length: 78, dtype: int64

# %%
Date_map=data1.Date.value_counts().to_dict()
Date_map
# Out:
# {'28/10/2017': 879,
#  '17/03/2018': 753,
#  '9/12/2017': 723,
#  '24/02/2018': 723,
#  '25/11/2017': 682,
#  '18/11/2017': 681,
#  '3/03/2018': 647,
#  '6/01/2018': 624,
#  '27/05/2017': 610,
#  '23/09/2017': 591,
#  '14/10/2017': 559,
#  '11/11/2017': 555,
#  '16/09/2017': 546,
#  '21/10/2017': 527,
#  '3/06/2017': 525,
#  '26/08/2017': 523,
#  '17/06/2017': 489,
#  '7/10/2017': 476,
#  '27/11/2016': 456,
#  '3/09/2017': 450,
#  '12/08/2017': 449,
#  '24/06/2017': 449,
#  '9/09/2017': 448,
#  '19/08/2017': 441,
#  '4/03/2017': 416,
#  '25/02/2017': 415,
#  '17/02/2018': 414,
#  '10/12/2016': 407,
#  '29/07/2017': 385,
#  '1/07/2017': 383,
#  '12/11/2016': 382,
#  '18/03/2017': 377,
#  '15/10/2016': 360,
#  '3/12/2016': 360,
#  '8/07/2017': 352,
#  '22/07/2017': 350,
#  '8/04/2017': 350,
#  '18/06/2016': 343,
#  '28/05/2016': 341,
#  '20/05/2017': 341,
#  '15/07/2017': 336,
#  '19/11/2016': 336,
#  '8/10/2016': 317,
#  '13/05/2017': 312,
#  '7/05/2016': 309,
#  '17/09/2016': 302,
# ...

# %%
data1.Date= data1.Date.map(Date_map)
data1.head(10)
# Out:
#     Suburb  Address  Rooms      Price  SellerG  Date  Distance  Postcode  \
# 1      102        1      2  1480000.0      650   360       2.5    3067.0
# 2      102        1      2  1035000.0      650    35       2.5    3067.0
# 4      102        4      3  1465000.0      650   416       2.5    3067.0
# 5      102        1      3   850000.0      650   416       2.5    3067.0
# 6      102        1      4  1600000.0     2735   284       2.5    3067.0
# 10     102        1      2   941000.0     2532   309       2.5    3067.0
# 11     102        1      3  1876000.0     2735   309       2.5    3067.0
# 14     102        1      2  1636000.0     2735   317       2.5    3067.0
# 15     102        1      3  1000000.0     2532   317       2.5    3067.0
# 16     102        1      2   745000.0     2532   317       2.5    3067.0
#
#     Bedroom2  Bathroom  ...  Longtitude             Regionname  Propertycount  \
# 1    2.00000  1.000000  ...  144.998400  Northern Metropolitan         4019.0
# ...

# %%
data1.CouncilArea.value_counts()
# Out:
# Boroondara City Council           2520
# Darebin City Council              2349
# Moreland City Council             1790
# Glen Eira City Council            1643
# Moonee Valley City Council        1584
# Melbourne City Council            1502
# Banyule City Council              1457
# Brimbank City Council             1366
# Bayside City Council              1311
# Maribyrnong City Council          1221
# Hume City Council                 1036
# Monash City Council               1007
# Port Phillip City Council          952
# Yarra City Council                 918
# Stonnington City Council           884
# Manningham City Council            842
# Hobsons Bay City Council           799
# Kingston City Council              735
# Whittlesea City Council            709
# Wyndham City Council               492
# Whitehorse City Council            435
# Maroondah City Council             356
# Knox City Council                  287
# Melton City Council                243
# ...

# %%
CouncilArea_map=data1.CouncilArea.value_counts().to_dict()

data1.CouncilArea= data1.CouncilArea.map(CouncilArea_map)
data1.head(10)
# Out:
#     Suburb  Address  Rooms      Price  SellerG  Date  Distance  Postcode  \
# 1      102        1      2  1480000.0      650   360       2.5    3067.0
# 2      102        1      2  1035000.0      650    35       2.5    3067.0
# 4      102        4      3  1465000.0      650   416       2.5    3067.0
# 5      102        1      3   850000.0      650   416       2.5    3067.0
# 6      102        1      4  1600000.0     2735   284       2.5    3067.0
# 10     102        1      2   941000.0     2532   309       2.5    3067.0
# 11     102        1      3  1876000.0     2735   309       2.5    3067.0
# 14     102        1      2  1636000.0     2735   317       2.5    3067.0
# 15     102        1      3  1000000.0     2532   317       2.5    3067.0
# 16     102        1      2   745000.0     2532   317       2.5    3067.0
#
#     Bedroom2  Bathroom  ...  Longtitude             Regionname  Propertycount  \
# 1    2.00000  1.000000  ...  144.998400  Northern Metropolitan         4019.0
# ...

# %%
Regionname_map=data1.Regionname.value_counts().to_dict()
Regionname_map
data1.Regionname= data1.Regionname.map(Regionname_map)
data1.head(10)
# Out:
#     Suburb  Address  Rooms      Price  SellerG  Date  Distance  Postcode  \
# 1      102        1      2  1480000.0      650   360       2.5    3067.0
# 2      102        1      2  1035000.0      650    35       2.5    3067.0
# 4      102        4      3  1465000.0      650   416       2.5    3067.0
# 5      102        1      3   850000.0      650   416       2.5    3067.0
# 6      102        1      4  1600000.0     2735   284       2.5    3067.0
# 10     102        1      2   941000.0     2532   309       2.5    3067.0
# 11     102        1      3  1876000.0     2735   309       2.5    3067.0
# 14     102        1      2  1636000.0     2735   317       2.5    3067.0
# 15     102        1      3  1000000.0     2532   317       2.5    3067.0
# 16     102        1      2   745000.0     2532   317       2.5    3067.0
#
#     Bedroom2  Bathroom  ...  Longtitude  Regionname  Propertycount  \
# 1    2.00000  1.000000  ...  144.998400        7864         4019.0
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
min_max=MinMaxScaler()
df_minmax=pd.DataFrame(min_max.fit_transform(data1),columns=data1.columns)
df_minmax
# Out:
#          Suburb   Address     Rooms     Price   SellerG      Date  Distance  \
# 0      0.139118  0.000000  0.066667  0.125506  0.237381  0.408210  0.051975
# 1      0.139118  0.000000  0.066667  0.085470  0.237381  0.037628  0.051975
# 2      0.139118  1.000000  0.133333  0.124157  0.237381  0.472064  0.051975
# 3      0.139118  0.000000  0.133333  0.068826  0.237381  0.472064  0.051975
# 4      0.139118  0.000000  0.200000  0.136302  1.000000  0.321551  0.051975
# ...         ...       ...       ...       ...       ...       ...       ...
# 27242  0.342975  0.333333  0.200000  0.125506  0.149232  0.822121  0.130977
# 27243  0.342975  0.000000  0.066667  0.072245  0.137162  0.822121  0.130977
# 27244  0.342975  0.000000  0.066667  0.055780  0.149232  0.822121  0.130977
# 27245  0.342975  0.000000  0.133333  0.094917  0.771397  0.822121  0.130977
# 27246  0.342975  0.000000  0.066667  0.084121  0.079737  0.822121  0.130977
#
# ...

# %%
data1.corr()['Price']
# Out:
# Suburb           0.055870
# Address          0.037582
# Rooms            0.465238
# Price            1.000000
# SellerG          0.061020
# Date             0.044431
# Distance        -0.211382
# Postcode         0.045002
# Bedroom2         0.380414
# Bathroom         0.379460
# Landsize         0.027098
# BuildingArea     0.066239
# YearBuilt       -0.231203
# CouncilArea      0.185795
# Lattitude       -0.190457
# Longtitude       0.174476
# Regionname       0.166129
# Propertycount   -0.058910
# Car_random       0.151958
# Type_t          -0.063657
# Type_u          -0.346388
# Method_S         0.002691
# Method_SA       -0.008840
# Method_SP       -0.104156
# Method_VB        0.074224
# Name: Price, dtype: float64
